# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Import Modules
from pprint import pprint
import json
from bs4 import BeautifulSoup
from urllib.parse import urlencode
import re

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

import os
os.getcwd()
# Out:
# '/home/jovyan/work/Fraud_Detection'

# %%
# Import Data
data = pd.read_json('data/data.json')

# %%
data.head(3)
# Out:
#          acct_type  approx_payout_date  body_length  channels country  \
# 0  fraudster_event          1266062400         3852         5      US
# 1          premium          1296720000         3499         0      US
# 2          premium          1296172800         2601         8      US
#
#   currency  delivery_method  \
# 0      USD              0.0
# 1      USD              1.0
# 2      USD              1.0
#
#                                          description    email_domain  \
# 0  <p><a href="http://s432.photobucket.com/albums...       gmail.com
# 1  <p>Join us for a quick, one-night, community-b...         ruf.org
# 2  <h3><span class="subcategory"><strong>Teacher ...  pvsd.k12.ca.us
#
#    event_created  ...                                       ticket_types  \
# 0     1262739706  ...  [{'event_id': 527017, 'cost': 25.0, 'availabil...
# 1     1293832670  ...  [{'event_id': 786878, 'cost': 35.0, 'availabil...
# 2     1291090956  ...  [{'event_id': 787337, 'cost': 93.51, 'availabi...
#
#    user_age  user_created  user_type                 venue_address  \
# 0        36    1259613950          1         717 Washington Avenue
# 1       149    1280942776          3
# 2       214    1272559388          3  10100 Pioneer Blvd Suite 100
#
#    venue_country  venue_latitude  venue_longitude  \
# 0             US       25.777471       -80.133433
# 1             US       32.776566       -79.930922
# 2             US       33.944201      -118.080419
#
#                                venue_name venue_state
# 0             INK Nightclub - South Beach          FL
# 1                 The Charleston, SC area          SC
# 2  Los Angeles County Office of Education          CA
#
# [3 rows x 44 columns]

# %% [markdown]
# # Create Pandas Profile Report

# %%
# Create Pandas Profile -> Export HTML
# from pandas_profiling import ProfileReport

# Run Profiling about Movie Metadata
# profile = ProfileReport(data, title="Fraud Data Profiling Report", explorative=True)

# %%
# Store Profile in data folder
# profile.to_file("data/fraud_data_profile.html")

# %% [markdown]
# # EDA

# %% [markdown]
# #### Description Feature (HTML)

# %%
sample = data['description'][8]

soup = BeautifulSoup(sample)

# soup

# Ended Up Dropping Description

# %% [markdown]
# #### Ticket_Types Feature (List[dict])

# %%
sample = data['ticket_types'][500]

sample
# Out:
# [{'event_id': 104011,
#   'cost': 5.0,
#   'availability': 1,
#   'quantity_total': 80,
#   'quantity_sold': 19}]

# %% [markdown]
# # Check API Data

# %%
from src.api_client import *

event_api = EventAPIClient()

def _call(client:object) -> pd.DataFrame:
    return client.get_data()

# %%
sample_call = _call(event_api)

# %%
# pprint(sample_call[0])

# %%
pd.DataFrame(sample_call)
# Out:
#    body_length  channels country currency  delivery_method  \
# 0           92         6      GB      GBP              0.0
#
#                                          description      email_domain  \
# 0  <p><img src="webkit-fake-url://33F81254-F314-4...  curlvolution.com
#
#    event_created   event_end  event_published  ...  user_age  user_created  \
# 0     1365025065  1369530000     1.365028e+09  ...       348    1334952837
#
#    user_type  venue_address  venue_country venue_latitude venue_longitude  \
# 0          3                                    51.508279        0.020237
#
#                      venue_name  venue_state sequence_number
# 0  Crowne Plaza Hotel Docklands                         2459
#
# [1 rows x 39 columns]

# %%
from src.cleaner import *

# %%
# Out:
#       country currency  delivery_method                email_domain  \
# 0          US      USD              0.0                   gmail.com
# 1          US      USD              1.0                     ruf.org
# 2          US      USD              1.0              pvsd.k12.ca.us
# 3          IE      EUR              1.0        irishtabletennis.com
# 4          US      USD              0.0  artsandbusinesscouncil.org
# ...       ...      ...              ...                         ...
# 14332      US      USD              0.0                   yahoo.com
# 14333      US      USD              1.0                      me.com
# 14334              USD              0.0                   yahoo.com
# 14335      US      USD              0.0              velvetlist.com
# 14336      GB      GBP              0.0                   gmail.com
#
#        event_start  fb_published listed  object_id  \
# 0       1265594400             0      y     527017
# 1       1296255600             0      n     786878
# 2       1295713800             0      y     787337
# 3       1360702800             0      y     885645
# 4       1297440000             1      y    1114349
# ...            ...           ...    ...        ...
# 14332   1361232000             0      n    5456442
# 14333   1365123600             0      y    5465112
# 14334   1368327600             1      y    5465732
# 14335   1360890000             0      y    5465810
# 14336   1360740600             0      n    5492990
#
#                                         payee_name payout_type  \
# 0
# 1                                              RUF       CHECK
# 2                    University Preparation School       CHECK
# 3                                                          ACH
# 4      Arts and Business Council or Greater Boston       CHECK
# ...                                            ...         ...
# 14332
# 14333      ARCS Foundation Inc., San Diego Chapter       CHECK
# 14334                                                      ACH
# 14335                                                      ACH
# 14336                                                      ACH
#
#                                         previous_payouts  user_age  user_type  \
# 0                                                     []        36          1
# 1      [{'name': 'RUF', 'created': '2010-10-01 01:10:...       149          3
# 2      [{'name': 'Danielle Severn', 'created': '2010-...       214          3
# 3      [{'name': '', 'created': '2010-11-09 01:10:15'...       889          3
# 4      [{'name': 'Arts and Business Council or Greate...        35          3
# ...                                                  ...       ...        ...
# 14332                                                 []         0          1
# 14333  [{'name': 'ARCS Foundation Inc., San Diego Cha...      1374          4
# 14334  [{'name': '', 'created': '2013-05-16 03:26:11'...        84          4
# 14335  [{'name': '', 'created': '2010-11-30 01:11:30'...       812          3
# 14336                                                 []         0          1
#
#       venue_country  venue_latitude  venue_longitude  \
# 0                US       25.777471       -80.133433
# 1                US       32.776566       -79.930922
# 2                US       33.944201      -118.080419
# 3              None             NaN              NaN
# 4                US       42.353848       -71.044276
# ...             ...             ...              ...
# 14332            US       39.373780       -76.629921
# 14333            US       32.778906      -117.209791
# 14334            US       30.041819       -89.957130
# 14335            US       40.862283       -73.911363
# 14336            GB       51.460131        -2.586503
#
#                                               venue_name       venue_state
# 0                            INK Nightclub - South Beach                FL
# 1                                The Charleston, SC area                SC
# 2                 Los Angeles County Office of Education                CA
# 3                                                   None              None
# 4                                      Fish & Richardson                MA
# ...                                                  ...               ...
# 14332                                      Elkridge Club                MD
# 14333  Hilton San Diego Resort and Spa (Hilton Missio...                CA
# 14334                     Fleur De Lis Ballroom NUMBER 2                LA
# 14335                                   Salsa con fuego                 NY
# 14336                        massage salon private house  Bristol, City Of
#
# [14337 rows x 18 columns]
