# %%
# %load_ext autoreload
# %autoreload 2
import pprint
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
import seaborn as sns

# API
from src.api_client import EventAPIClient

plt.style.use('ggplot')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data = pd.read_json('data/data.json')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14337 entries, 0 to 14336
# Data columns (total 44 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   acct_type           14337 non-null  object
#  1   approx_payout_date  14337 non-null  int64
#  2   body_length         14337 non-null  int64
#  3   channels            14337 non-null  int64
#  4   country             14256 non-null  object
#  5   currency            14337 non-null  object
#  6   delivery_method     14321 non-null  float64
#  7   description         14337 non-null  object
#  8   email_domain        14337 non-null  object
#  9   event_created       14337 non-null  int64
#  10  event_end           14337 non-null  int64
#  11  event_published     14238 non-null  float64
#  12  event_start         14337 non-null  int64
#  13  fb_published        14337 non-null  int64
#  14  gts                 14337 non-null  float64
# ...

# %%
def get_value_counts(df):
    cols = df.columns
    for col in cols:
        print(col, df[col].value_counts())

# %%
get_value_counts(data)
# Out:
# premium             12373
# fraudster_event       851
# fraudster             437
# spammer_limited       218
# spammer_warn          144
# tos_warn               91
# spammer_noinvite       84
# tos_lock               77
# locked                 54
# fraudster_att           5
# spammer_web             2
# spammer                 1
# Name: acct_type, dtype: int64
# 1357466400    28
# 1357430400    20
# 1357480800    12
# 1357470000    11
# 1367535600    11
#               ..
# 1356642000     1
# 1353528900     1
# 1343530800     1
# 1366603200     1
# 1356595200     1
# Name: approx_payout_date, Length: 9655, dtype: int64
# 0        829
# 870       25
# 1615      24
# 108       24
# 131       17
#         ...
# 8706       1
# 36563      1
# 10755      1
# 59086      1
# 8055       1
# Name: body_length, Length: 6595, dtype: int64
# 8     3364
# 0     2941
# 5     2459
# 11    2312
# 6     1736
# 4      556
# 12     470
# 10     237
# 13     232
# 9       20
# 7       10
# ...

# %%
# What do we get from the API?
client = EventAPIClient()
client.get_data()[0]
# Out:
# {'body_length': 2677, 'channels': 6, 'country': 'US', 'currency': 'USD', 'delivery_method': 0.0, 'description': '<p style="text-align: center;"><span style="font-family: georgia,palatino;">\xa0</span></p>\r\n<p style="text-align: center;">\xa0</p>\r\n<p class="MsoNormal" style="margin-top: 0in; margin-right: 0in; margin-bottom: .0001pt; margin-left: 1.0in; text-align: center; text-indent: -1.0in; line-height: normal;" align="center"><span style="font-family: georgia,palatino;"><strong style="mso-bidi-font-weight: normal;"><span style="font-size: 18pt;">BOKX 109 American Prime Presents:</span></strong></span></p>\r\n<p class="MsoNormal" style="margin-top: 0in; margin-right: 0in; margin-bottom: .0001pt; margin-left: 1.0in; text-align: center; text-indent: -1.0in; line-height: normal;" align="center"><span style="font-family: georgia,palatino;"><strong style="mso-bidi-font-weight: normal;"><span style="font-size: 18pt;">A 70’s Cocktail Party</span></strong></span></p>\r\n<p class="MsoNo
# ...

# %%
features = [str(i) for i in transaction.keys()]
features_to_keep_API = ['country', 'currency', 'delivery_method', 'email_domain', 'event_start', 
                    'fb_published', 'listed', 'object_id', 'payee_name', 'payout_type', 
                    'previous_payouts', 'user_age', 'user_type', 'venue_country', 'venue_latitude', 
                    'venue_longitude', 'venue_name', 'venue_state']
